# %%
import sys
import os
import numpy as np

sys.path.append(os.path.abspath("../../mathematical_models"))
from mathematical_models.s_on_f import ScalarOnFunctionModel

sys.path.append(os.path.abspath("../../optimizers"))
from optimizers.cordex_discrete import CordexDiscrete

sys.path.append(os.path.abspath("../../utilities"))
from utilities.plotting.plot_fun import subplot_results, subplot_b_spline_results

# %% [markdown]
# ### Settings

# %%
N = 4 # runs
Kx_family = 'step'
Kx = [[4]]
Kb = [[2]] # Polynomial
epochs = 100
refinement_epochs = 100
lvls = [-1, 1]
model = ScalarOnFunctionModel(Kx=Kx[0], Kb= Kb[0], Kx_family=Kx_family)

# %%
optimizer = CordexDiscrete(model, runs=N, levels=lvls)
best_design, best_objective_value = optimizer.optimize(epochs=epochs, refinement_epochs=refinement_epochs)
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 446.73it/s]

# %%
subplot_results(2,2, np.linspace(0, 1, 1000), best_design)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 subplot_results(2,2, np.linspace(0, 1, 1000), best_design)
#
# File ~/Documents/code/system_optidex/utilities/plotting/plot_fun.py:49, in subplot_results(sub_x, sub_y, T, results, style, size, save)
#      47         row_to_plot += 1
#      48 if save:
# ---> 49     fig2 = plt.savefig('./results/myexp.png')
#      50 fig = plt.gcf()
#      51 return fig
#
# File ~/miniforge3/envs/optidex/lib/python3.10/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# ...
